# %%
# Functions in Python 

# defining a function 
def sum_of_numbers (para1, para2):
    return para1 + para2

sum_of_numbers(5,6)
# Out:
# 11

# %%
# function that prints name and age

def information (name, age):
    return f"my name is {name} and i'm {age} years old"

output = information ('pratham', 24)
print(output)

# Functions to perform additon that takes three numbers and returns their sum
def sum(a,b,c):
    output = a + b + c
    return output

sum(1,3,5)

# Even or Odd checker using function 
number = int(input("Enter the number you waant"))
                   
def EvenOddChecker(number):
    if number % 2 == 0:
        return f'It is an even number {number}'
    else:
        return f'It is an odd number {number}'

finalOutput = EvenOddChecker(number)

print(finalOutput)


# Square of a number
num = int(input("Enter the number of your choice"))

def squareRoot(number):
    squareRootval = number ** 2
    return squareRootval

squareRoot(num)


# Maximum of Two number 
num1 = int(input("Enter the first number"))
num2 = int(input("Enter the second number"))

def maximumNumber(a, b):
    if(a > b):
        return f"{a} is greater than {b}"
    elif a == b:
        return f"{a} is equal to {b}"
    else:
        return f"{b} is greater than {a}"

maximumNumber(num1, num2)

# Simple Calculators in python using the function
num1 = int(input("Enter the first number of your choice"))
num2 = int(input("Enter the second number of your choice"))
allowdedOperators = [ '+', '-', '*', '/']

while True:
    operator = input("Enter the operator")
    if(operator in allowdedOperators):
        break
    else: 
        print("Invalid operator choice")

def calculator(a, b , opeartor):
    if(operator == '+'):
        return a + b
    elif (operator == '-'):
        return a - b
    elif (operator == '*'):
        return a * b
    elif operator == '/':
        return a / b

result = calculator(num1, num2, operator)
print(result)
# Out:
# my name is pratham and i'm 24 years old
# Enter the number you waant 4
# It is an even number 4
# Enter the number of your choice 4
# Enter the first number 5
# Enter the second number 6
# Enter the first number of your choice 5
# Enter the second number of your choice 6
# Enter the operator +
# 11
